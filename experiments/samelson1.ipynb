# %% [markdown]
# ## Samelson model of the Berkley Jet
# The Bickley jet

# %%
# Base imports and path setting
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import jax
import jax.numpy as jnp
import diffrax as dfx
from time import time

import sys
import os
from os.path import dirname
cwd = os.getcwd()
sys.path.append(dirname(cwd))

# %%
# Relative import and macroscopic configs
from src.flows import samelson_flow, trajectory_plot, stream_plot
from src.lyapunov import *

jax.config.update("jax_enable_x64", True)
rng = np.random.default_rng(seed=42069)
FIG_PATH = dirname(cwd) + "/figs_backflow/"

# %%
# Flow selection and parameters
rhs = samelson_flow
pars = {
    "A0": 0.5,
    "C": 0.25,
    "L": 2,
    "h": 0.1,
    "wf": 0.56,
}

# Integration options
dt = 0.001
N_iters = 2e4
steps = 500

timesteps = np.linspace(0, steps*dt*N_iters, 30000)

burns = 0.2

solver = dfx.Kvaerno5()
stepsc = dfx.PIDController(rtol=1e-8, atol=1e-8)
term = dfx.ODETerm(rhs)
saveat = dfx.SaveAt(ts=timesteps)

# Graph boundaries and grids
X_space = np.linspace(-2*np.pi, 2*np.pi, 400)
Y_space = np.linspace(-5, 5, 400)
X, Y = np.meshgrid(X_space, Y_space)
U, V = rhs(t=0, z=(X, Y), params=pars)

# %%
# Animation of the flow
starting_lines = np.array([i.flatten() for i in np.meshgrid(
                            np.linspace(-2*np.pi, 2*np.pi, 200),
                            np.linspace(-5, 5, 200),
                            indexing="ij"
                           )]).T

dens=3

fig, ax = plt.subplots()
stream = ax.streamplot(X, Y, U, V, density=dens, start_points=starting_lines)

def animate(ti):
    ax.clear()
    ax.grid(True)
    U, V = rhs(t=ti, z=(X, Y), params=pars)
    stream = ax.streamplot(X, Y, U, V, density=dens, start_points=starting_lines)
    print(ti)
    return stream

#anim = animation.FuncAnimation(fig, animate, frames=np.linspace(0, 2*np.pi/pars.get("wf", 1), 100), interval=50, blit=False, repeat=False)
#anim.save( FIG_PATH + '/samelson.gif', writer='imagemagick', fps=30)
# plt.show()

# %%
# Preliminary test: topological regime of the flow at different parameters
pars_1 = {
    "A0": 0.5,
    "C": 0.25,
    "L": 2,
    "h": 0.0,
    "wf": 0.56,
}

U_full, V_full = rhs(t=np.pi/(pars.get("wf")), z=(X, Y), params=pars_1)
plt.streamplot(X, Y, U_full, V_full, density=3, color=np.sqrt(U_full**2 + V_full**2), cmap='plasma')
plt.grid()
plt.savefig(FIG_PATH + "Sam_Perturbed_flow1.png", dpi=1500)
plt.show()

pars_2 = {
    "A0": 1,
    "C": 0.25,
    "L": 2,
    "h": 0.0,
    "wf": 0.56,
}

U_full, V_full = rhs(t=np.pi/(pars.get("wf")), z=(X, Y), params=pars_2)
plt.streamplot(X, Y, U_full, V_full, density=3, color=np.sqrt(U_full**2 + V_full**2), cmap='plasma')
plt.grid()
plt.savefig(FIG_PATH + "Sam_Perturbed_flow1.png", dpi=1500)
plt.show()

# %%
# First experiment 1: lyapunov computation interval variation for different initial conditions
# Setup and calculations
pars_list = pars.copy()
pars_list.update({"h": 0})

shapes = (5, 11)
step_range = jnp.linspace(1, 2001, shapes[1])
STEP, X0, = jnp.meshgrid(step_range, jnp.linspace(-jnp.pi, jnp.pi, shapes[0]) - 0.3)
z0_range = jnp.array([jnp.concat(X0), jnp.concat(X0)]).T

var_compute = make_batch_fast_lyapunov(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns), jacobian=False)
var_lyap_ext = jax.jit(
    jax.vmap(var_compute, in_axes=(0, None, {"A0": None, "C": None, "L": None, "h": None, "wf": None}, 0))
)

var_step_mlyap = jnp.sort(var_lyap_ext(z0_range, 0, pars_list, jnp.concat(STEP)*dt)).reshape(*shapes, 2)[:, :, -1]

# %%
for i in range(var_step_mlyap.shape[0]):
    plt.scatter(step_range, var_step_mlyap[i, :])
plt.grid(True)
plt.xlabel("# Iteration"); plt.ylabel("Leading lyap-exp value"); plt.title("Unpertrubed map integration interval variation")
plt.savefig(FIG_PATH + "Interval_variation_z0.png", dpi=500)
plt.show()

# %%
# First experiment 2: lyapunov computation interval variation
# Setup and calculations
z0 = jnp.array([np.pi/2, 0])
pars_list = pars.copy()
pars_list.update({"h": 0})

step_range = jnp.linspace(1, 30, 50)

var_compute = make_batch_fast_lyapunov(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns), jacobian=False)
var_lyap_ext = jax.jit(
    jax.vmap(var_compute, in_axes=(None, None, {"A0": None, "C": None, "L": None, "h": None, "wf": None}, 0))
)

var_step_mlyap = jnp.sort(var_lyap_ext(z0, 0, pars_list, step_range*dt))[:, -1]

# %%
plt.scatter(step_range, var_step_mlyap)
plt.grid(True)
plt.xlabel("# Iteration"); plt.ylabel("Leading lyap-exp value"); plt.title("Unpertrubed map integration interval variation")
plt.savefig(FIG_PATH + "Interval_variation.png", dpi=500)
plt.show()

# %%
# First experiment 3: trajectory check

# %% [markdown]
# ### Results comment
# After ~ 20 steps, the Lyapunov exponents stabilize, but this is due to the fact that the map is integrated for a time which is effectively #iters time the base amount. In another code (lyap_test), we see that for dt = 0.001 and fixed total time, the steps minimize the exponent at about ~1000. In this code, since jax compilation does not seem to permit fixed integration time, step size is set to 50 as a compromise between good resolution of the trajectories, speed of execution and lyapunov exponents precision.

# %%
# Third experiment: perturbation parameters variation
# Setup and calculations
z0 = jnp.array([np.pi/2, 0])
pars_list = pars.copy()
shapes = (6, 6)
H, WF = jnp.meshgrid(jnp.logspace(-2, 0, shapes[0]), jnp.logspace(-2, 1, shapes[1]))

pars_list.update({"h": jnp.concat(H)})
pars_list.update({"wf": jnp.concat(WF)})

var_par_compute = make_batch_fast_lyapunov(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns), jacobian=False)
var_par_lyap = jax.jit(
    jax.vmap(var_par_compute, in_axes=(None, None, {"A0": None, "C": None, "L": None, "h": 0, "wf": 0}, None))
)

var_cum_lyaps = jnp.sort(var_par_lyap(z0, 0, pars_list, steps*dt))[:, -1]

# %%
# Plots
for cum, h, wf in zip(var_cum_lyaps, jnp.concat(H), jnp.concat(WF)):
    print(f"Lyapunov exponents extimate for parameters h = {h:.4f}, wf = {wf:.4f}: {cum:.5f}")

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
for cum, h, wf in zip(var_cum_lyaps.reshape(6, 6), H, WF):
    markerline, stemlines, baseline = ax.stem(
        h, wf, cum, linefmt='grey', markerfmt='D')
    markerline.set_markerfacecolor('none')
    stemlines.set(linestyle="--")
    baseline.remove()

plt.xlabel("Perturbation amplitude")
plt.ylabel("Perturbation frequency")
plt.grid(True)
plt.savefig(FIG_PATH + "Pars_variation_gross.png", dpi=1500)
plt.show()

# Perturbated flow
#plt.streamplot(X, Y, U , V, density=3)

"""pert_pars = pars.copy()

pert_pars.update({"h": 0.5})
U_full, V_full = rhs(t=np.pi/(pars.get("wf")), z=(X, Y), params=pert_pars)
plt.streamplot(X, Y, U_full, V_full, density=3, color=np.sqrt(U_full**2 + V_full**2), cmap='plasma')
plt.grid()
plt.savefig(FIG_PATH + "Sam_Perturbed_flow.png", dpi=1500)
plt.show()
"""
# Out:
# Lyapunov exponents extimate for parameters h = 0.0100, wf = 0.0100: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0251, wf = 0.0100: 0.00013
# Lyapunov exponents extimate for parameters h = 0.0631, wf = 0.0100: 0.00010
# Lyapunov exponents extimate for parameters h = 0.1585, wf = 0.0100: 0.00010
# Lyapunov exponents extimate for parameters h = 0.3981, wf = 0.0100: 0.00000
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.0100: 0.00674
# Lyapunov exponents extimate for parameters h = 0.0100, wf = 0.0398: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0251, wf = 0.0398: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0631, wf = 0.0398: 0.00003
# Lyapunov exponents extimate for parameters h = 0.1585, wf = 0.0398: 0.00005
# Lyapunov exponents extimate for parameters h = 0.3981, wf = 0.0398: 0.00996
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.0398: 0.01915
# Lyapunov exponents extimate for parameters h = 0.0100, wf = 0.1585: 0.00007
# Lyapunov exponents extimate for parameters h = 0.0251, wf = 0.1585: 0.00010
# Lyapunov exponents extimate for parameters h = 0.0631, wf = 0.1585: 0.00008
# Lyapunov exponents extimate for parameters h = 0.1585, wf = 0.1585: 0.02344
# Lyapunov exponents extimate for parameters h = 0.3981, wf = 0.1585: 0.03221
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.1585: 0.02803
# Lyapunov exponents extimate for parameters h = 0.0100, wf = 0.6310: 0.00013
# Lyapunov exponents extimate for parameters h = 0.0251, wf = 0.6310: 0.00002
# Lyapunov exponents extimate for parameters h = 0.0631, wf = 0.6310: 0.00004
# Lyapunov exponents extimate for parameters h = 0.1585, wf = 0.6310: 0.00003
# Lyapunov exponents extimate for parameters h = 0.3981, wf = 0.6310: 0.00005
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.6310: 0.00007
# Lyapunov exponents extimate for parameters h = 0.0100, wf = 2.5119: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0251, wf = 2.5119: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0631, wf = 2.5119: 0.00000
# Lyapunov exponents extimate for parameters h = 0.1585, wf = 2.5119: 0.00012
# Lyapunov exponents extimate for parameters h = 0.3981, wf = 2.5119: 0.00013
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 2.5119: 0.00012
# Lyapunov exponents extimate for parameters h = 0.0100, wf = 10.0000: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0251, wf = 10.0000: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0631, wf = 10.0000: 0.00001
# Lyapunov exponents extimate for parameters h = 0.1585, wf = 10.0000: 0.00011
# Lyapunov exponents extimate for parameters h = 0.3981, wf = 10.0000: 0.00007
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 10.0000: 0.00015
# 'pert_pars = pars.copy()\n\npert_pars.update({"h": 0.5})\nU_full, V_full = rhs(t=np.pi/(pars.get("wf")), z=(X, Y), params=pert_pars)\nplt.streamplot(X, Y, U_full, V_full, density=3, color=np.sqrt(U_full**2 + V_full**2), cmap=\'plasma\')\nplt.grid()\nplt.savefig(FIG_PATH + "Sam_Perturbed_flow.png", dpi=1500)\nplt.show()\n'

# %% [markdown]
# ### Osservazioni
# Vediamo che al crescere di $w_f$ sopra $~ 0.46$ il sistema ha esponente di lyapunov minore.
# Il mLCE tende a decrescere per $h > 3$

# %%
# Third experiment: parameters variation (finer)
# Setup and calculations
z0 = jnp.array([np.pi/2, 0])
pars_list = pars.copy()
shapes = (10, 10)
H, WF = jnp.meshgrid(jnp.logspace(jnp.log(0.05), 0, shapes[0]), jnp.linspace(0.02, 0.6, shapes[1]))

pars_list.update({"h": jnp.concat(H)})
pars_list.update({"wf": jnp.concat(WF)})

var_par_compute = make_batch_fast_lyapunov(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns), jacobian=False)
var_par_lyap = jax.jit(
    jax.vmap(var_par_compute, in_axes=(None, None, {"A0": None, "C": None, "L": None, "h": 0, "wf": 0}, None))
)

var_cum_lyaps = jnp.sort(var_par_lyap(z0, 0, pars_list, steps*dt))[:, -1]

# %%
# Plots
for cum, h, wf in zip(var_cum_lyaps, jnp.concat(H), jnp.concat(WF)):
    print(f"Lyapunov exponents extimate for parameters h = {h:.4f}, wf = {wf:.4f}: {cum:.5f}")

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
for cum, h, wf in zip(var_cum_lyaps.reshape(*shapes), H, WF):
    markerline, stemlines, baseline = ax.stem(
        h, wf, cum, linefmt='grey', markerfmt='D')
    markerline.set_markerfacecolor('none')
    stemlines.set(linestyle="--", alpha=0.5)
    baseline.remove()

plt.xlabel("Perturbation amplitude")
plt.ylabel("Perturbation frequency")
plt.grid(True)
plt.savefig(FIG_PATH + "Pars_variation_fine.png", dpi=1500)
plt.show()

# Perturbated flow
#plt.streamplot(X, Y, U , V, density=3)
# Out:
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.0200: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.0200: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.0200: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.0200: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.0200: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.0200: 0.00007
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.0200: 0.00001
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.0200: 0.00012
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.0200: 0.00727
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.0200: 0.01133
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.0844: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.0844: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.0844: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.0844: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.0844: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.0844: 0.00004
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.0844: 0.00014
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.0844: 0.00024
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.0844: 0.02102
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.0844: 0.02934
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.1489: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.1489: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.1489: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.1489: 0.00014
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.1489: 0.00009
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.1489: 0.00015
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.1489: 0.00008
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.1489: 0.02141
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.1489: 0.03334
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.1489: 0.03497
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.2133: 0.00005
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.2133: 0.00006
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.2133: 0.00014
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.2133: 0.00001
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.2133: 0.00007
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.2133: 0.01788
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.2133: 0.02289
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.2133: 0.03038
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.2133: 0.02949
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.2133: 0.03150
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.2778: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.2778: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.2778: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.2778: 0.00008
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.2778: 0.00007
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.2778: 0.00001
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.2778: 0.02551
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.2778: 0.03239
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.2778: 0.04055
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.2778: 0.02380
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.3422: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.3422: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.3422: 0.00014
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.3422: 0.00011
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.3422: 0.00006
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.3422: 0.00002
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.3422: 0.01256
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.3422: 0.02447
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.3422: 0.04719
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.3422: 0.03369
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.4067: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.4067: 0.00013
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.4067: 0.00000
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.4067: 0.00002
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.4067: 0.00284
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.4067: 0.00531
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.4067: 0.02573
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.4067: 0.02550
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.4067: 0.04750
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.4067: 0.03394
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.4711: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.4711: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.4711: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.4711: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.4711: 0.00013
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.4711: 0.00002
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.4711: 0.00012
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.4711: 0.03395
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.4711: 0.03790
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.4711: 0.00214
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.5356: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.5356: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.5356: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.5356: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.5356: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.5356: 0.00015
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.5356: 0.00009
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.5356: 0.00002
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.5356: 0.03402
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.5356: 0.00001
# Lyapunov exponents extimate for parameters h = 0.0010, wf = 0.6000: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0022, wf = 0.6000: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0047, wf = 0.6000: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0101, wf = 0.6000: 0.00016
# Lyapunov exponents extimate for parameters h = 0.0217, wf = 0.6000: 0.00017
# Lyapunov exponents extimate for parameters h = 0.0466, wf = 0.6000: 0.00001
# Lyapunov exponents extimate for parameters h = 0.1003, wf = 0.6000: 0.00007
# Lyapunov exponents extimate for parameters h = 0.2159, wf = 0.6000: 0.00012
# Lyapunov exponents extimate for parameters h = 0.4647, wf = 0.6000: 0.00007
# Lyapunov exponents extimate for parameters h = 1.0000, wf = 0.6000: 0.00580

# %%
# Third experiment: parameters variation (finest)
# Setup and calculations
z0 = jnp.array([np.pi/2, 0])
pars_list = pars.copy()
shapes = (10, 10)
H, WF = jnp.meshgrid(jnp.logspace(jnp.log10(0.05), jnp.log10(0.5), shapes[0]), jnp.linspace(0.1, 0.6, shapes[1]))

pars_list.update({"h": jnp.concat(H)})
pars_list.update({"wf": jnp.concat(WF)})

var_par_compute = make_batch_fast_lyapunov(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns), jacobian=False)
var_par_lyap = jax.jit(
    jax.vmap(var_par_compute, in_axes=(None, None, {"A0": None, "C": None, "L": None, "h": 0, "wf": 0}, None))
)

var_cum_lyaps = jnp.sort(var_par_lyap(z0, 0, pars_list, steps*dt))[:, -1]

# %%
# Plots
for cum, h, wf in zip(var_cum_lyaps, jnp.concat(H), jnp.concat(WF)):
    print(f"Lyapunov exponents extimate for parameters h = {h:.4f}, wf = {wf:.4f}: {cum:.5f}")

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
for cum, h, wf in zip(var_cum_lyaps.reshape(*shapes), H, WF):
    markerline, stemlines, baseline = ax.stem(
        h, wf, cum, linefmt='grey', markerfmt='D')
    markerline.set_markerfacecolor('none')
    stemlines.set(linestyle="--", alpha=0.5)
    baseline.remove()

plt.xlabel("Perturbation amplitude")
plt.ylabel("Perturbation frequency")
plt.grid(True)
plt.savefig(FIG_PATH + "Pars_variation_finest.png", dpi=1500)
plt.show()

# Perturbated flow
#plt.streamplot(X, Y, U , V, density=3)
# Out:
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.0200: 0.00005
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.0200: 0.00008
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.0200: 0.00007
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.0200: 0.00009
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.0200: 0.00001
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.0200: 0.00009
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.0200: 0.00010
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.0200: 0.00009
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.0200: 0.00002
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.0200: 0.00588
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.0844: 0.00003
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.0844: 0.00006
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.0844: 0.00007
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.0844: 0.00003
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.0844: 0.00004
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.0844: 0.00009
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.0844: 0.01885
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.0844: 0.01326
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.0844: 0.02252
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.0844: 0.02681
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.1489: 0.00005
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.1489: 0.00004
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.1489: 0.00019
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.1489: 0.00001
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.1489: 0.01508
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.1489: 0.01059
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.1489: 0.02271
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.1489: 0.02865
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.1489: 0.03366
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.1489: 0.03383
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.2133: 0.02013
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.2133: 0.01946
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.2133: 0.02541
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.2133: 0.02718
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.2133: 0.03022
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.2133: 0.00148
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.2133: 0.03529
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.2133: 0.03142
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.2133: 0.03384
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.2133: 0.02213
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.2778: 0.00002
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.2778: 0.00020
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.2778: 0.02405
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.2778: 0.02717
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.2778: 0.03371
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.2778: 0.03681
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.2778: 0.03791
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.2778: 0.04002
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.2778: 0.04095
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.2778: 0.04131
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.3422: 0.00002
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.3422: 0.00005
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.3422: 0.00004
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.3422: 0.02634
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.3422: 0.02851
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.3422: 0.03039
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.3422: 0.03703
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.3422: 0.04341
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.3422: 0.04313
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.3422: 0.04306
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.4067: 0.00501
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.4067: 0.01664
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.4067: 0.02397
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.4067: 0.03083
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.4067: 0.02795
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.4067: 0.03527
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.4067: 0.03458
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.4067: 0.03674
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.4067: 0.04506
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.4067: 0.04538
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.4711: 0.00005
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.4711: 0.00008
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.4711: 0.00003
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.4711: 0.00014
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.4711: 0.00168
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.4711: 0.03117
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.4711: 0.03431
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.4711: 0.03219
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.4711: 0.04210
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.4711: 0.04396
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.5356: 0.00015
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.5356: 0.00014
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.5356: 0.00012
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.5356: 0.00009
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.5356: 0.00013
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.5356: 0.00006
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.5356: 0.00007
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.5356: 0.02562
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.5356: 0.03274
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.5356: 0.03292
# Lyapunov exponents extimate for parameters h = 0.0500, wf = 0.6000: 0.00007
# Lyapunov exponents extimate for parameters h = 0.0646, wf = 0.6000: 0.00001
# Lyapunov exponents extimate for parameters h = 0.0834, wf = 0.6000: 0.00015
# Lyapunov exponents extimate for parameters h = 0.1077, wf = 0.6000: 0.00035
# Lyapunov exponents extimate for parameters h = 0.1391, wf = 0.6000: 0.00019
# Lyapunov exponents extimate for parameters h = 0.1797, wf = 0.6000: 0.00025
# Lyapunov exponents extimate for parameters h = 0.2321, wf = 0.6000: 0.00010
# Lyapunov exponents extimate for parameters h = 0.2997, wf = 0.6000: 0.00265
# Lyapunov exponents extimate for parameters h = 0.3871, wf = 0.6000: 0.00584
# Lyapunov exponents extimate for parameters h = 0.5000, wf = 0.6000: 0.00020

# %% [markdown]
# ### Results
# Maximum mLCE obtained at $w_f = 0.56$
# For the stream to not be completely destroyed, we chose $h = 0.1$

# %%
# Second experiment 1: lyapunov exponents for 100 random initial condition

# Define random ranges
rand_flurry = jnp.array([rng.random(100)*4*np.pi - 2*np.pi, rng.random(100)*8 - 4]).T
t0 = 0.0

# Build mappable function
rand_compute = make_batch_lyapunov_solver(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns))
batched_lyap = jax.jit(
    jax.vmap(rand_compute, in_axes=(0, None, None, None))
)

# Execute
rand_trajects, rand_cum_lyaps = batched_lyap(rand_flurry, t0, pars, steps*dt)

# %%
# Flow at different times with flurry
plt.streamplot(X, Y, U , V, density=3, color="green",)
U_flur, V_flur = rhs(t=np.pi/(pars.get("wf")), z=(X, Y), params=pars)
plt.streamplot(X, Y, U_flur, V_flur, density=3, color=np.sqrt(U_flur**2 + V_flur**2), cmap='plasma',)
plt.scatter(*rand_flurry.T, c="cyan", zorder=10)
plt.grid()
plt.xlabel("x"); plt.ylabel("y"); plt.title("Flow at t=0 and t= T/4")
plt.savefig(FIG_PATH + "Flurry_flow.png", dpi=1500)
plt.show()

# Plot and results
for cum in rand_cum_lyaps:
    plt.plot(cum)
plt.grid(True)
plt.xlabel("# Iteration"); plt.ylabel("Exponent value"); plt.title("Lyapunov exponents of randomly distributed initial conditions")
plt.savefig(FIG_PATH + "Rand_lyaps.png")
plt.show()
lyap_ext = rand_cum_lyaps.mean(axis=0)[-1, :]
lyap_std = rand_cum_lyaps.std(axis=0)[-1, :]
print(f"Lyapunov exponents extimate (averaged over random trajectories): {lyap_ext} +- {lyap_std}")

# Trajectories
rand_trajects_trasp = np.transpose(rand_trajects, axes=(0, -1, -2))
#with plt.style.context('Solarize_Light2'):
plt.xlim(left=-10)
for traj in rand_trajects_trasp:
    plt.plot(*traj, linewidth=0.8)
plt.grid(True)
plt.savefig(FIG_PATH + "Rand_trajects.png", dpi=1500)
plt.show()
# Out:
# Lyapunov exponents extimate (averaged over random trajectories): [ 0.00683308 -0.00683308] +- [0.00753874 0.00753874]

# %%
# Second experiment 2: non-random condition (unperturbed)

pars_unp = pars.copy()
pars_unp.update({"h": 0})

# Define points
flurry = jnp.concat([jnp.array([jnp.zeros(9), jnp.linspace(-4, 4, 9)]).T,
                     jnp.array([jnp.linspace(-2*jnp.pi, 0, 21), jnp.full(21, -jnp.pi/2)]).T,
                     jnp.array([jnp.linspace(-jnp.pi, jnp.pi, 21), jnp.full(21, jnp.pi/2)]).T,
                                ])
t0_batch = jnp.zeros(len(flurry))

# Build mappable function
flurry_compute = make_batch_lyapunov_solver(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns))
batched_lyap = jax.jit(
    jax.vmap(flurry_compute, in_axes=(0, 0, None, None))
)

# Execute
flurry_trajects, flurry_cum_lyaps = batched_lyap(flurry, t0_batch, pars_unp, steps*dt)

# %%
# Plot and results
for cum in flurry_cum_lyaps:
    plt.plot(cum)
plt.grid(True)
plt.xlabel("# Iteration"); plt.ylabel("Exponent value"); plt.title("Lyapunov exponents of chosen initial conditions")
plt.savefig(FIG_PATH + "Flurry_lyaps_unpertrubed.png")
plt.show()
lyap_ext = flurry_cum_lyaps.mean(axis=0)[-1, :]
lyap_std = flurry_cum_lyaps.std(axis=0)[-1, :]
print(f"Lyapunov exponents extimate (averaged over trajectories): {lyap_ext} +- {lyap_std}")

# Trajectories
flurry_trajects_trasp = np.transpose(flurry_trajects, axes=(0, -1, -2))
#with plt.style.context('Solarize_Light2'):
fig, ax = plt.subplots()
for traj in flurry_trajects_trasp:
    plot_wrapped(*traj, ax=ax, linewidth=0.75)
plt.grid(True)
plt.xlabel("x"); plt.ylabel("y"); plt.title("Trajectories")
plt.savefig(FIG_PATH + "Flurry_trajects_unpertrubed.png", dpi=1500)
plt.show()
# Out:
# Lyapunov exponents extimate (averaged over trajectories): [ 0.00013892 -0.00013892] +- [0.00013066 0.00013066]

# %%
# Second experiment 2: non-random condition

pars.update({"h": 0.4, "wf": 0.4067})

# Define points
flurry = jnp.concat([jnp.array([jnp.zeros(9), jnp.linspace(-4, 4, 9)]).T,
                     jnp.array([jnp.linspace(-2*jnp.pi, 0, 21), jnp.full(21, -jnp.pi/2)]).T,
                     jnp.array([jnp.linspace(-jnp.pi, jnp.pi, 21), jnp.full(21, jnp.pi/2)]).T,
                                ])
t0_batch = jnp.zeros(len(flurry))

# Build mappable function
flurry_compute = make_batch_lyapunov_solver(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns))
batched_lyap = jax.jit(
    jax.vmap(flurry_compute, in_axes=(0, 0, None, None))
)

# Execute
flurry_trajects, flurry_cum_lyaps = batched_lyap(flurry, t0_batch, pars, steps*dt)

# %%
# Plot and results
for cum in flurry_cum_lyaps:
    plt.plot(cum)
plt.grid(True)
plt.xlabel("# Iteration"); plt.ylabel("Exponent value"); plt.title("Lyapunov exponents of chosen initial conditions")
plt.savefig(FIG_PATH + "Flurry_lyaps" + str(pars["h"]) + "_" + str(pars["wf"]) +".png")
plt.show()
lyap_ext = flurry_cum_lyaps.mean(axis=0)[-1, :]
lyap_std = flurry_cum_lyaps.std(axis=0)[-1, :]
print(f"Lyapunov exponents extimate (averaged over trajectories): {lyap_ext} +- {lyap_std}")

# Trajectories
flurry_trajects_trasp = np.transpose(flurry_trajects, axes=(0, -1, -2))
#with plt.style.context('Solarize_Light2'):
fig, ax = plt.subplots()
for traj in flurry_trajects_trasp:
    plot_wrapped(*traj, ax=ax, linewidth=0.6)
plt.grid(True)
plt.xlabel("x"); plt.ylabel("y"); plt.title("Trajectories")
plt.savefig(FIG_PATH + "Flurry_trajects" + str(pars["h"]) + "_" + str(pars["wf"]) + ".png", dpi=1500)
plt.show()
# Out:
# Lyapunov exponents extimate (averaged over trajectories): [ 0.04050171 -0.04050171] +- [0.01100063 0.01100063]

# %% [markdown]
# ### Interpretazione del risultato
# La stima dei coefficienti di Lyapunov è entro 2 sigma dallo zero, fatto che potrebbe essere dato dalla quantità relativamente alta di punti inizializzati all'interno delle strutture cicloidi del flusso, che rimangono intrappolati in traiettorie stabili.
# Dalla figura infatti se ne vedono alcune che rimangono all'interno delle cicloidi, sia grandi che piccole, oppure ancora nei flussi sopra e sotto l'area centrale nell'asse y, anche se queste vediamo che possono rientrare nella serpentina.
# In conclusione, stimare come media su condizioni random potrebbe non portare a risultati significativi, in quanto vi sono zone della mappa dal comportamento qualitativamente diverso, e non è detto che queste comunichino con le altre per l'ampiezza di perturbazione considerata.

# %%
# Second experiment 2: lyapuov map

pars.update({"h": 0.4, "wf": 0.4067})

# Define points
flurry = jnp.concat([jnp.array([jnp.zeros(9), jnp.linspace(-4, 4, 9)]).T,
                     jnp.array([jnp.linspace(-2*jnp.pi, 0, 21), jnp.full(21, -jnp.pi/2)]).T,
                     jnp.array([jnp.linspace(-jnp.pi, jnp.pi, 21), jnp.full(21, jnp.pi/2)]).T,
                                ])

# Build mappable function
flurry_compute = make_batch_lyapunov_solver(flow=rhs, solver=solver, dt=dt, stepsize=stepsc, n_intervals=N_iters, burn_in=int(N_iters*burns))
batched_lyap = jax.jit(
    jax.vmap(flurry_compute, in_axes=(0, None, None, None))
)

# Execute
flurry_trajects, flurry_cum_lyaps = batched_lyap(flurry, 0, pars, steps*dt)

# %%
flurry_lyaps = jnp.sort(flurry_cum_lyaps)[:, -1, -1]

norm = mpl.colors.Normalize(vmin=np.min(flurry_lyaps), vmax=np.max(flurry_lyaps), clip=False)
norm_lyaps = norm(flurry_lyaps)
cmap = mpl.colormaps["plasma"]
colors = cmap(norm_lyaps)

# Trajectories
flurry_trajects_trasp = np.transpose(flurry_trajects, axes=(0, -1, -2))
#with plt.style.context('Solarize_Light2'):
fig, ax = plt.subplots()
for traj, col in zip(flurry_trajects_trasp, norm_lyaps):
    plot_wrapped(*traj, ax=ax, kind="scatter", s=0.6, color=cmap(col), zorder=1-col)
plt.grid(True)
plt.xlabel("x"); plt.ylabel("y"); plt.title("lyapunov exponent map")
plt.savefig(FIG_PATH + "Lyapunov_map_" + str(pars["h"]) + "_" + str(pars["wf"]) + "_reverse.png", dpi=1500)
plt.show()

# %% [markdown]
# ### Interpretazioni del risultato
# Vediamo che le prime cinque traiettorie graficate (secondo il cycling di default di matplotlib.pyplot.plot, dalla prima blu alla viola) seguono il flusso perturbato che è simile a quello analizzato in precedenza.
# Le utlime sei, invece, mostrano un andamento più erratico, con le ultime che saltano da una cicloide all'altra "tagliando" il flusso imperturbato, o addirittura procedendo nel verso contrario del flusso.
# Andando poi a graficare il flusso a metà periodo della perturbazione (ampiezza h = 1) si nota la comparsa di un flusso centrale in senso opposto e la distruzione delle cicloidi più piccole.
